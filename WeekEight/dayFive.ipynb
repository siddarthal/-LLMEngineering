# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# dont build objects twice below and here
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:39:08 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c0d75c4d-1ea0-450b-845a-70fcd7260f2b)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c0d75c4d-1ea0-450b-845a-70fcd7260f2b)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c0d75c4d-1ea0-450b-845a-70fcd7260f2b)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c0d75c4d-1ea0-450b-845a-70fcd7260f2b)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] Retrying in 1s [Retry 1/5].
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] Retrying in 1s [Retry 1/5].
# [2026-02-28 15:39:18 +0530] [Agents] [WARNING] Retrying in 1s [Retry 1/5].
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 agent_framework = DealAgentFramework()
# ----> 2 agent_framework.init_agents_as_needed()
#       4 with gr.Blocks(title="The Price is Right", fill_width=True) as ui:
#       6     initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
#
# File ~/projects/LLMEngineeringLearning/WeekEight/deal_agent_framework.py:62, in DealAgentFramework.init_agents_as_needed(self)
#      60 if not self.planner:
#      61     self.log("Initializing Agent Framework")
# ---> 62     self.planner = PlanningAgent(self.collection)
#      63     self.log("Agent Framework is ready")
#
# File ~/projects/LLMEngineeringLearning/WeekEight/agents/planning_agent.py:21, in PlanningAgent.__init__(self, collection)
#      19 self.log("Planning Agent is initializing")
#      20 self.scanner = ScannerAgent()
# ---> 21 self.ensemble = EnsembleAgent(collection)
#      22 self.messenger = MessagingAgent()
#      23 self.log("Planning Agent is ready")
#
# File ~/projects/LLMEngineeringLearning/WeekEight/agents/ensemble_agent.py:19, in EnsembleAgent.__init__(self, collection)
#      17 self.log("Initializing Ensemble Agent")
#      18 self.specialist = SpecialistAgent()
# ---> 19 self.frontier = FrontierAgent(collection)
#      20 self.neural_network = NeuralNetworkAgent()
#      21 self.preprocessor = Preprocessor()
#
# File ~/projects/LLMEngineeringLearning/WeekEight/agents/frontier_agent.py:24, in FrontierAgent.__init__(self, collection)
#      22 self.log("Frontier Agent is setting up with OpenAI")
#      23 self.collection = collection
# ---> 24 self.model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
#      25 self.log("Frontier Agent is ready")
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:327, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)    314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)    325     == self._model_config["model_type"]
#     326 ):
# --> 327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#     330         cache_folder=cache_folder,
#     331         revision=revision,
#     332         trust_remote_code=trust_remote_code,
#     333         local_files_only=local_files_only,
#     334         model_kwargs=model_kwargs,
#     335         tokenizer_kwargs=tokenizer_kwargs,
#     336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#     339     modules = self._load_auto_model(
#     340         model_name_or_path,
#     341         token=token,
#    (...)    349         has_modules=has_modules,
#     350     )
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:2183, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    2165 """
#    2166 Loads a full SentenceTransformer model using the modules.json file.
#    2167
#    (...)   2180     OrderedDict[str, nn.Module]: An ordered dictionary containing the modules of the model.
#    2181 """
#    2182 # Check if the config_sentence_transformers.json file exists (exists since v2 of the framework)
# -> 2183 config_sentence_transformers_json_path = load_file_path(
#    2184     model_name_or_path,
#    2185     "config_sentence_transformers.json",
#    2186     token=token,
#    2187     cache_folder=cache_folder,
#    2188     revision=revision,
#    2189     local_files_only=local_files_only,
#    2190 )
#    2191 if config_sentence_transformers_json_path is not None:
#    2192     with open(config_sentence_transformers_json_path, encoding="utf8") as fIn:
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/sentence_transformers/util/file_io.py:96, in load_file_path(model_name_or_path, filename, subfolder, token, cache_folder, revision, local_files_only)
#      94 file_path = Path(subfolder, filename)
#      95 try:
# ---> 96     return hf_hub_download(
#      97         model_name_or_path,
#      98         filename=file_path.name,
#      99         subfolder=file_path.parent.as_posix(),
#     100         revision=revision,
#     101         library_name="sentence-transformers",
#     102         token=token,
#     103         cache_dir=cache_folder,
#     104         local_files_only=local_files_only,
#     105     )
#     106 except Exception:
#     107     return None
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)   1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1070, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1066         return pointer_path
#    1068 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1069 # If we can't, a HEAD request error is returned.
# -> 1070 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1071     repo_id=repo_id,
#    1072     filename=filename,
#    1073     repo_type=repo_type,
#    1074     revision=revision,
#    1075     endpoint=endpoint,
#    1076     proxies=proxies,
#    1077     etag_timeout=etag_timeout,
#    1078     headers=headers,
#    1079     token=token,
#    1080     local_files_only=local_files_only,
#    1081     storage_folder=storage_folder,
#    1082     relative_filename=relative_filename,
#    1083 )
#    1085 # etag can be None for several reasons:
#    1086 # 1. we passed local_files_only.
#    1087 # 2. we don't have a connection
#    (...)   1093 # If the specified revision is a commit hash, look inside "snapshots".
#    1094 # If the specified revision is a branch or tag, look inside "refs".
#    1095 if head_call_error is not None:
#    1096     # Couldn't make a HEAD call => let's try to find a local file
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1543, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1541 try:
#    1542     try:
# -> 1543         metadata = get_hf_file_metadata(
#    1544             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1545         )
#    1546     except EntryNotFoundError as http_error:
#    1547         if storage_folder is not None and relative_filename is not None:
#    1548             # Cache the non-existence of the file
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1460, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1457 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1459 # Retrieve metadata
# -> 1460 r = _request_wrapper(
#    1461     method="HEAD",
#    1462     url=url,
#    1463     headers=hf_headers,
#    1464     allow_redirects=False,
#    1465     follow_relative_redirects=True,
#    1466     proxies=proxies,
#    1467     timeout=timeout,
#    1468 )
#    1469 hf_raise_for_status(r)
#    1471 # Return
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:283, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     281 # Recursively follow relative redirects
#     282 if follow_relative_redirects:
# --> 283     response = _request_wrapper(
#     284         method=method,
#     285         url=url,
#     286         follow_relative_redirects=False,
#     287         **params,
#     288     )
#     290     # If redirection, we redirect only relative paths.
#     291     # This is useful in case of a renamed repository.
#     292     if 300 <= response.status_code <= 399:
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:306, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     303     return response
#     305 # Perform request and return if status_code is not in the retry list.
# --> 306 response = http_backoff(method=method, url=url, **params)
#     307 hf_raise_for_status(response)
#     308 return response
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:306, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     303     kwargs["data"].seek(io_obj_initial_pos)
#     305 # Perform request and return if status_code is not in the retry list.
# --> 306 response = session.request(method=method, url=url, **kwargs)
#     307 if response.status_code not in retry_on_status_codes:
#     308     return response
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:95, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      93     logger.debug(f"Send: {_curlify(request)}")
#      94 try:
# ---> 95     return super().send(request, *args, **kwargs)
#      96 except requests.RequestException as e:
#      97     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/projects/LLMEngineeringLearning/.venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()
agent_framework = DealAgentFramework()

# %%
agent_framework.run()
# Out:
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:40:28 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-02-28 15:40:35 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and OpenAI
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and OpenAI
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-02-28 15:40:36 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# /Users/siddarthalegala/projects/LLMEngineeringLearning/WeekEight/agents/deals.py:53: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")
# [2026-02-28 15:40:42 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 20 deals not already scraped
# [2026-02-28 15:40:42 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 20 deals not already scraped
# [2026-02-28 15:40:42 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-02-28 15:40:42 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-02-28 15:40:53 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:40:53 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:40:53 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:40:53 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# 15:40:56 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/qwen2.5-coder:1.5b
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/qwen2.5-coder:1.5b
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] [Specialist Agent] calling pricer service to calculate price
# [2026-02-28 15:40:56 +0530] [Agents] [INFO] [Specialist Agent] calling pricer service to calculate price
# [2026-02-28 15:41:26 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2026-02-28 15:41:26 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2026-02-28 15:41:26 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-02-28 15:41:26 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [2026-02-28 15:41:29 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-02-28 15:41:29 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-02-28 15:41:29 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-02-28 15:41:29 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1199.99
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1199.99
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $372.88
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $372.88
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $1092.28
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $1092.28
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $742.28
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $742.28
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-02-28 15:41:30 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:41:30 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:41:30 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:41:30 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# 15:41:33 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:41:33 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:41
# [Opportunity(deal=Deal(product_description='The Samsung Galaxy Watch Ultra is a premium 47mm LTE Titanium smartwatch designed for both style and functionality. It features a circular display made with durable materials suitable for outdoor activities, providing GPS tracking, health monitoring, and custom apps for various needs. The robust design integrates a range of smart features including notifications, music control, and heart rate tracking, making it an ideal companion for fitness enthusiasts and tech-savvy users alike.', price=350.0, url='https://www.dealnews.com/Samsung-Galaxy-Watch-Ultra-47-mm-LTE-Titanium-Smartwatch-up-to-350-off-w-Trade-in-free-shipping/21663266.html?iref=rss-c142'), estimate=773.8138460593241, discount=423.8138460593241),
#  Opportunity(deal=Deal(product_description="The Refurbished Unlocked Apple iPhone 14 Pro Max offers an impressive 256GB storage and a huge display, perfect for both media consumption and productivity. Enjoy advanced camera technology for stunning photos. This model is designed to provide a seamless user experience with 5G capabilities for faster downloads and streaming. Refurbished to high standards, it comes in various colors and can support all the latest apps from the App Store, accommodating any Apple enthusiast's needs.", price=705.0, url='https://www.dealnews.com/products/Apple/Unlocked-Apple-iPhone-14-Pro-Max-256-GB-Smartphone/462808.html?iref=rss-c142'), estimate=930.8824204895075, discount=225.88242048950747),
#  Opportunity(deal=Deal(product_description='LG 75" Class UT75 Series LED 4K UHD Smart TV (2024) is a large-screen LED television with 4K (2160p) resolution and support for High Dynamic Range (HDR) including HDR10. It runs LG\'s webOS smart platform for streaming apps and smart features, and is designed for use as a primary living-room TV with a 75-inch diagonal panel offering wide viewing angles and integrated tuner and input options for modern home entertainment setups.', price=350.0, url='https://slickdeals.net/f/19256935-lg-75-class-ut75-series-led-4k-uhd-smart-webos-tv-350?utm_source=rss&utm_content=fp&utm_medium=RSS2'), estimate=1092.280446044922, discount=742.280446044922)]

# %%
# !uv run price_is_right.py
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:47:11 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-02-28 15:47:19 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and OpenAI
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and OpenAI
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-02-28 15:47:20 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# /Users/siddarthalegala/projects/LLMEngineeringLearning/WeekEight/agents/deals.py:53: MarkupResemblesLocatorWarning:
#
# The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#
# [2026-02-28 15:47:24 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 19 deals not already scraped
# [2026-02-28 15:47:24 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 19 deals not already scraped
# [2026-02-28 15:47:24 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-02-28 15:47:24 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-02-28 15:47:36 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:47:36 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:47:36 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# [2026-02-28 15:47:36 +0530] [Agents] [INFO]
# LiteLLM completion() model= qwen2.5-coder:1.5b; provider = ollama
# 15:47:39 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/qwen2.5-coder:1.5b
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/qwen2.5-coder:1.5b
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] [Specialist Agent] calling pricer service to calculate price
# [2026-02-28 15:47:39 +0530] [Agents] [INFO] [Specialist Agent] calling pricer service to calculate price
# [2026-02-28 15:48:17 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-02-28 15:48:17 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-02-28 15:48:17 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-02-28 15:48:17 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.96s/it]
# [2026-02-28 15:48:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-02-28 15:48:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-02-28 15:48:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-02-28 15:48:19 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $49.99
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $49.99
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $37.68
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $37.68
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $49.76
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $49.76
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $22.16
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $22.16
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-02-28 15:48:21 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15