# %% [markdown]
# ## We will be using collab from here below is the url

# %% [markdown]
# https://colab.research.google.com/drive/1KbehvvDBvz3KGvXTQhYQr6BqINOlIN1_?usp=sharing

# %% [markdown]
# ### But first lets try something lovely

# %%
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the color red to someone who has never been able to see"
model_name = "gpt-4.1-mini"

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
