# %% [markdown]
# # Week 7 Day 1
#
# # "THE PRICE IS RIGHT" Capstone Project
#
# This week - fine tune an open-source model!
#
# A model that can estimate how much something costs, from its description.
#
# # Order of play
#
# DAY 1: QLoRA
# DAY 2: Prompt Data and Base Model
# DAY 3: Train Part 1
# DAY 4: Train Part 2
# DAY 5: Eval

# %% [markdown]
# ## Below is the place where you find execution

# %% [markdown]
# https://colab.research.google.com/drive/1ASm4NNU8rfWOifr6a-CT0eA7Ghh-9Hvj?usp=sharing
